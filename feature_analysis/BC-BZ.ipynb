# %%
import pandas as pd
import seaborn as sns
from scipy import stats

# %%
data = pd.read_csv("../data/train.csv", index_col="Id")

# %%
columns = ["BC","BD ","BN","BP","BQ","BR","BZ","Class"]
data = data[columns]
data["BQ"] = data["BQ"].fillna(data["BQ"].mean()) #Since the column BQ has missing entries
#Filtering outliers
z_scores = stats.zscore(data)
threshold = 3
data_filtered = data[(abs(z_scores) < threshold).all(axis=1)]
data_filtered.head()
# Out:
#                       BC         BD        BN          BP          BQ  \
# Id
# 000ff2bfdfe9    5.555634  4126.58731  22.5984  175.638726  152.707705
# 007255e47698    1.229900  5496.92824  19.4205  155.868030   14.754720
# 013f2bd269f5    1.229900  5135.78024  26.4825  128.988531  219.320160
# 043ac50845d5    1.229900  4169.67738  23.6577  237.282264   11.050410
# 044fb8a146ec  102.151980  5728.73412  24.0108  324.546318  149.717165
#
#                        BR          BZ  Class
# Id
# 000ff2bfdfe9   823.928241  257.432377      1
# 007255e47698    51.216883  257.432377      0
# 013f2bd269f5   482.141594  257.432377      0
# 043ac50845d5   661.518640  257.432377      0
# 044fb8a146ec  6074.859475  257.432377      1

# %% [markdown]
# ## Distribution for columns BC to BZ ##

# %%
#sns.kdeplot(data=data_filtered[columns[0]],fill=True) -> Normal
#sns.kdeplot(data=data_filtered[columns[1]],fill=True) -> Normal
#sns.kdeplot(data=data_filtered[columns[2]],fill=True) -> Weird
#sns.kdeplot(data=data_filtered[columns[3]],fill=True) -> Normal
#sns.kdeplot(data=data_filtered[columns[4]],fill=True) -> Weird
#sns.kdeplot(data=data_filtered[columns[5]],fill=True) -> Normal
#sns.kdeplot(data=data_filtered[columns[6]],fill=True) -> Normal but weird

# %% [markdown]
# ## Correlation between each column and the Class column ##

# %%
sns.swarmplot(x = data_filtered["Class"], y = data_filtered[columns[0]])
# Out:
# c:\Users\Guilherme Alt\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 60.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Class', ylabel='BC'>
# c:\Users\Guilherme Alt\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 72.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Guilherme Alt\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 19.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x = data_filtered["Class"], y = data_filtered[columns[1]])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='BD '>
# c:\Users\Guilherme Alt\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 7.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x = data_filtered["Class"], y = data_filtered[columns[2]])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='BN'>

# %%
sns.swarmplot(x = data_filtered["Class"], y = data_filtered[columns[3]])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='BP'>
# c:\Users\Guilherme Alt\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 22.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x = data_filtered["Class"], y = data_filtered[columns[4]])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='BQ'>
# c:\Users\Guilherme Alt\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 15.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x = data_filtered["Class"], y = data_filtered[columns[5]])
# Out:
# c:\Users\Guilherme Alt\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Class', ylabel='BR'>
# c:\Users\Guilherme Alt\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 40.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x = data_filtered["Class"], y = data_filtered[columns[6]])
# Out:
# c:\Users\Guilherme Alt\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 73.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Guilherme Alt\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 28.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Class', ylabel='BZ'>
# c:\Users\Guilherme Alt\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 77.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
